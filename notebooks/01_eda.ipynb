# %% [markdown]
# # EDA - Potato Disease Classification
#
# Exploración del dataset: conteo de clases, muestras de imágenes, tamaños.

# %%
from pathlib import Path

data_dir = Path("../data/raw")
for class_dir in sorted(data_dir.iterdir()):
    if class_dir.is_dir():
        n = len(list(class_dir.glob("*")))
        print(f"{class_dir.name}: {n} imagenes")
